# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("/home/jachinshen/Downloads/fireNumber/1.jpg")

# %%
img = cv2.GaussianBlur(img, (61, 61), 0)

# %%
plt.imshow(img)
plt.show()
